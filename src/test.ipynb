# %%
from graph.build_graph import get_graph
# Out:
# 14:58:01 - LiteLLM:WARNING: utils.py:2705 - register_model: model=gpt-oss-120b not in built-in cost map and no prefix/region variant matched; cache cost fields will default to 0. To track cache cost, add cache_creation_input_token_cost and cache_read_input_token_cost to model_info
# 14:58:01 - LiteLLM:WARNING: utils.py:2705 - register_model: model=llama-3.1-8b-instant not in built-in cost map and no prefix/region variant matched; cache cost fields will default to 0. To track cache cost, add cache_creation_input_token_cost and cache_read_input_token_cost to model_info
# 14:58:01 - LiteLLM:WARNING: utils.py:2705 - register_model: model=llama-3.3-70b-versatile not in built-in cost map and no prefix/region variant matched; cache cost fields will default to 0. To track cache cost, add cache_creation_input_token_cost and cache_read_input_token_cost to model_info
# ...

# %%
graph = get_graph()
graph
